# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
tips = pd.read_csv('C:/Users/Shadam Gull/Desktop/CSV data/tips.csv')

# %%
tip.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tip.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000568C688>,
# ...
#       dtype=object)

# %%
tip.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
tip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
tips['tip']
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
tip.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tip.groupby(['sex']).sum()
# Out:
#         total_bill     tip  size
# sex
# Female     1570.95  246.51   214
# Male       3256.82  485.07   413

# %%
sns.swarmplot(x = "day", y = "total_bill", data = tips);

# %%
sns.catplot(x = "day", y = "total_bill", hue = "sex", data = tips);

# %%
sns.relplot(x = "total_bill", y = "tip", hue = "smoker", col = "day", data = tips);

# %%
sns.set(style="darkgrid")
sns.relplot(x = "total_bill", y = "tip", data = tips);

# %%
sns.relplot(x = "total_bill", y = "tip", hue= "smoker", data = tips);

# %%
sns.scatterplot(x = "total_bill", y = "tip", hue= "sex", data = tips);

# %% [markdown]
# Females tip less than the Male.

# %%
from sklearn import preprocessing, svm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X = np.array(tips['tip']).reshape(-1, 1)
y = np.array(tips['total_bill']).reshape(-1, 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
regr = LinearRegression()

# %%
regr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
X = np.array([[1, 1], [1, 2], [2, 2], [2, 3]]).reshape(-1, 1)
X
# Out:
# array([[1],
#        [1],
#        [1],
#        [2],
#        [2],
#        [2],
#        [2],
#        [3]])

# %%
print(regr.score(X_test, y_test))
# Out:
# 0.3299529201156106

# %%
y_pred = regr.predict(X_test)

# %%
plt.scatter(X_test, y_test, color ='b')
plt.plot(X_test, y_pred, color ='k')
  
plt.show()

# %%
tips.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
(tips['sex']=='Female').value_counts().plot(kind='bar')

# %%
df= pd.DataFrame(tips['day']=='Fri')

# %%
df
# Out:
#        day
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# ..     ...
# 239  False
# 240  False
# 241  False
# 242  False
# 243  False
#
# [244 rows x 1 columns]

# %%
sns.relplot(x = "total_bill", y = "tip", hue = "smoker", col = "time", data = tips);

# %%
pwd
# Out:
# 'C:\\Users\\Shadam Gull'
